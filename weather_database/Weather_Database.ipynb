# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 752

# %%
import requests

from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=88394b95d8291bfdd5ab6b5a53be27b8

# %%
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data_3 = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(3)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data_3.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Desc": city_weather_desc,})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 2 of Set 14 | busselton
# Processing Record 3 of Set 14 | ushuaia
# Processing Record 4 of Set 14 | manta
# Processing Record 5 of Set 14 | sabang
# Processing Record 6 of Set 14 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 14 | bubaque
# Processing Record 8 of Set 14 | punta arenas
# Processing Record 9 of Set 14 | bluff
# Processing Record 10 of Set 14 | san borja
# Processing Record 11 of Set 14 | krasnyy chikoy
# Processing Record 12 of Set 14 | shahreza
# Processing Record 13 of Set 14 | rikitea
# Processing Record 14 of Set 14 | zhigansk
# Processing Record 15 of Set 14 | krasnoselkup
# Processing Record 16 of Set 14 | salalah
# Processing Record 17 of Set 14 | nanortalik
# Processing Record 18 of Set 14 | thompson
# Processing Record 19 of Set 14 | klaksvik
# Processing Record 20 of Set 14 | patacamaya
# Processing Record 21 of Set 14 | onguday
# Processing Record 22 of Set 14 | wenling
# Processing Record 23 of Set 14 | lebu
# Processing Record 24 of Set 14 | atuona
# Processing Record 25 of Set 14 | olafsvik
# Processing Record 26 of Set 14 | ixtapa
# Processing Record 27 of Set 14 | longyearbyen
# Processing Record 28 of Set 14 | kapaa
# Processing Record 29 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 14 | hobart
# Processing Record 31 of Set 14 | vaini
# Processing Record 32 of Set 14 | upernavik
# Processing Record 33 of Set 14 | fort saint james
# Processing Record 34 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 35 of Set 14 | bambanglipuro
# Processing Record 36 of Set 14 | touros
# Processing Record 37 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 14 | port augusta
# Processing Record 39 of Set 14 | nassau
# Processing Record 40 of Set 14 | east london
# Processing Record 41 of Set 14 | vila franca do campo
# Processing Record 42 of Set 14 | bethel
# Processing Record 43 of Set 14 | port alfred
# Processing Record 44 of Set 14 | faanui
# Processing Record 45 of Set 14 | urbana
# Processing Record 46 of Set 14 | cabedelo
# Processing Record 47 of Set 14 | yar-sale
# Processing Record 48 of Set 14 | pevek
# Processing Record 49 of Set 14 | quesnel
# Processing Record 50 of Set 14 | nuuk
# Processing Record 1 of Set 15 | krasnovishersk
# Processing Record 2 of Set 15 | toora-khem
# Processing Record 3 of Set 15 | quilali
# Processing Record 4 of Set 15 | airai
# Processing Record 5 of Set 15 | hobyo
# Processing Record 6 of Set 15 | bermeo
# Processing Record 7 of Set 15 | flinders
# Processing Record 8 of Set 15 | sao felix do xingu
# Processing Record 9 of Set 15 | lasa
# Processing Record 10 of Set 15 | barrow
# Processing Record 11 of Set 15 | paciran
# Processing Record 12 of Set 15 | jamestown
# Processing Record 13 of Set 15 | sistranda
# Processing Record 14 of Set 15 | upington
# Processing Record 15 of Set 15 | trairi
# Processing Record 16 of Set 15 | la mana
# Processing Record 17 of Set 15 | nome
# Processing Record 18 of Set 15 | georgetown
# Processing Record 19 of Set 15 | vao
# Processing Record 20 of Set 15 | hermanus
# Processing Record 21 of Set 15 | cape town
# Processing Record 22 of Set 15 | san luis
# Processing Record 23 of Set 15 | berdigestyakh
# Processing Record 24 of Set 15 | lodja
# Processing Record 25 of Set 15 | katsuura
# Processing Record 26 of Set 15 | puerto carreno
# Processing Record 27 of Set 15 | bilma
# Processing Record 28 of Set 15 | mataura
# Processing Record 29 of Set 15 | carnarvon
# Processing Record 30 of Set 15 | minab
# Processing Record 31 of Set 15 | kahului
# Processing Record 32 of Set 15 | saint-philippe
# Processing Record 33 of Set 15 | north myrtle beach
# Processing Record 34 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 15 | albany
# Processing Record 36 of Set 15 | mungaa
# Processing Record 37 of Set 15 | laguna
# Processing Record 38 of Set 15 | avarua
# Processing Record 39 of Set 15 | kimbe
# Processing Record 40 of Set 15 | dingle
# Processing Record 41 of Set 15 | kawambwa
# Processing Record 42 of Set 15 | lerwick
# Processing Record 43 of Set 15 | sur
# Processing Record 44 of Set 15 | dikson
# Processing Record 45 of Set 15 | bacalar
# Processing Record 46 of Set 15 | cabo san lucas
# Processing Record 47 of Set 15 | port elizabeth
# Processing Record 48 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 15 | sogne
# Processing Record 50 of Set 15 | mangan
# Processing Record 1 of Set 16 | bathsheba
# Processing Record 2 of Set 16 | emba
# Processing Record 3 of Set 16 | valer
# Processing Record 4 of Set 16 | arraial do cabo
# Processing Record 5 of Set 16 | yumen
# Processing Record 6 of Set 16 | luderitz
# Processing Record 7 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 16 | tiksi
# Processing Record 9 of Set 16 | saint anthony
# Processing Record 10 of Set 16 | oulu
# Processing Record 11 of Set 16 | ylojarvi
# Processing Record 12 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 16 | ambon
# Processing Record 14 of Set 16 | hilo
# Processing Record 15 of Set 16 | saint-pierre
# Processing Record 16 of Set 16 | sorland
# Processing Record 17 of Set 16 | fairbanks
# Processing Record 18 of Set 16 | perth
# Processing Record 19 of Set 16 | imbituba
# Processing Record 20 of Set 16 | poum
# Processing Record 21 of Set 16 | marystown
# Processing Record 22 of Set 16 | baruun-urt
# Processing Record 23 of Set 16 | buala
# Processing Record 24 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 16 | cairns
# Processing Record 27 of Set 16 | choma
# Processing Record 28 of Set 16 | narsaq
# Processing Record 29 of Set 16 | pangnirtung
# Processing Record 30 of Set 16 | bengkulu
# Processing Record 31 of Set 16 | grand gaube
# Processing Record 32 of Set 16 | saldanha
# Processing Record 33 of Set 16 | ribeira grande
# Processing Record 34 of Set 16 | champerico
# Processing Record 35 of Set 16 | san jose
# Processing Record 36 of Set 16 | chumikan
# Processing Record 37 of Set 16 | zhangjiakou
# Processing Record 38 of Set 16 | durban
# Processing Record 39 of Set 16 | puerto colombia
# Processing Record 40 of Set 16 | nikolskoye
# Processing Record 41 of Set 16 | mar del plata
# Processing Record 42 of Set 16 | cidreira
# Processing Record 43 of Set 16 | eenhana
# Processing Record 44 of Set 16 | frederico westphalen
# Processing Record 45 of Set 16 | marsa matruh
# Processing Record 46 of Set 16 | ulladulla
# Processing Record 47 of Set 16 | maragogi
# Processing Record 48 of Set 16 | hurricane
# Processing Record 49 of Set 16 | nouadhibou
# Processing Record 50 of Set 16 | teguise
# Processing Record 1 of Set 17 | novikovo
# Processing Record 2 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 17 | wulanhaote
# City not found. Skipping...
# Processing Record 4 of Set 17 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 17 | manzanillo
# Processing Record 6 of Set 17 | clyde river
# Processing Record 7 of Set 17 | vanimo
# Processing Record 8 of Set 17 | qaanaaq
# Processing Record 9 of Set 17 | vestmannaeyjar
# Processing Record 10 of Set 17 | okhotsk
# Processing Record 11 of Set 17 | saint george
# Processing Record 12 of Set 17 | lompoc
# Processing Record 13 of Set 17 | henties bay
# Processing Record 14 of Set 17 | abu dhabi
# Processing Record 15 of Set 17 | vila do maio
# Processing Record 16 of Set 17 | castro
# Processing Record 17 of Set 17 | hofn
# Processing Record 18 of Set 17 | chokurdakh
# Processing Record 19 of Set 17 | puerto ayora
# Processing Record 20 of Set 17 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 17 | sitka
# Processing Record 22 of Set 17 | yenagoa
# Processing Record 23 of Set 17 | new norfolk
# Processing Record 24 of Set 17 | hasaki
# Processing Record 25 of Set 17 | merauke
# Processing Record 26 of Set 17 | palmer
# Processing Record 27 of Set 17 | mezen
# Processing Record 28 of Set 17 | diamantino
# Processing Record 29 of Set 17 | songjianghe
# Processing Record 30 of Set 17 | ovsyanka
# Processing Record 31 of Set 17 | nguru
# Processing Record 32 of Set 17 | bredasdorp
# Processing Record 33 of Set 17 | tucumcari
# Processing Record 34 of Set 17 | saint-joseph
# Processing Record 35 of Set 17 | omboue
# Processing Record 36 of Set 17 | ponta do sol
# Processing Record 37 of Set 17 | muyezerskiy
# Processing Record 38 of Set 17 | baikunthpur
# Processing Record 39 of Set 17 | ahipara
# Processing Record 40 of Set 17 | greensburg
# Processing Record 41 of Set 17 | lindi
# Processing Record 42 of Set 17 | kodiak
# Processing Record 43 of Set 17 | phu ly
# Processing Record 44 of Set 17 | beringovskiy
# Processing Record 45 of Set 17 | kaeo
# Processing Record 46 of Set 17 | yellowknife
# Processing Record 47 of Set 17 | yulara
# Processing Record 48 of Set 17 | kachikau
# City not found. Skipping...
# Processing Record 49 of Set 17 | tirat karmel
# Processing Record 50 of Set 17 | puerto rico
# Processing Record 1 of Set 18 | geraldton
# Processing Record 2 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 18 | kiama
# Processing Record 4 of Set 18 | bolshaya murta
# City not found. Skipping...
# Processing Record 5 of Set 18 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 18 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 18 | jaypur
# Processing Record 8 of Set 18 | mahenge
# Processing Record 9 of Set 18 | makakilo city
# Processing Record 10 of Set 18 | komsomolskiy
# Processing Record 11 of Set 18 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 18 | biltine
# Processing Record 13 of Set 18 | shemonaikha
# Processing Record 14 of Set 18 | meulaboh
# Processing Record 15 of Set 18 | kamaishi
# Processing Record 16 of Set 18 | alice springs
# Processing Record 17 of Set 18 | bichura
# Processing Record 18 of Set 18 | foumbot
# Processing Record 19 of Set 18 | huangzhai
# Processing Record 20 of Set 18 | ola
# Processing Record 21 of Set 18 | robertsport
# Processing Record 22 of Set 18 | chipinge
# Processing Record 23 of Set 18 | vysha
# Processing Record 24 of Set 18 | esna
# Processing Record 25 of Set 18 | samarai
# Processing Record 26 of Set 18 | saurimo
# Processing Record 27 of Set 18 | westport
# Processing Record 28 of Set 18 | pouebo
# Processing Record 29 of Set 18 | xuddur
# Processing Record 30 of Set 18 | altay
# Processing Record 31 of Set 18 | ulaangom
# Processing Record 32 of Set 18 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 18 | la vista
# Processing Record 34 of Set 18 | crab hill
# City not found. Skipping...
# Processing Record 35 of Set 18 | la ligua
# Processing Record 36 of Set 18 | charleville-mezieres
# Processing Record 37 of Set 18 | twin falls
# Processing Record 38 of Set 18 | tasiilaq
# Processing Record 39 of Set 18 | kantunilkin
# Processing Record 40 of Set 18 | okha
# Processing Record 41 of Set 18 | lakes entrance
# Processing Record 42 of Set 18 | yurty
# Processing Record 43 of Set 18 | los llanos de aridane
# Processing Record 44 of Set 18 | grindavik
# Processing Record 45 of Set 18 | severo-kurilsk
# Processing Record 46 of Set 18 | cumaribo
# City not found. Skipping...
# Processing Record 47 of Set 18 | leningradskiy
# Processing Record 48 of Set 18 | hokitika
# Processing Record 49 of Set 18 | kedrovyy
# Processing Record 50 of Set 18 | bambous virieux
# Processing Record 1 of Set 19 | stromness
# Processing Record 2 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 19 | vila
# Processing Record 4 of Set 19 | chatsu
# City not found. Skipping...
# Processing Record 5 of Set 19 | arrecife
# Processing Record 6 of Set 19 | kolokani
# Processing Record 7 of Set 19 | pisco
# Processing Record 8 of Set 19 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 19 | fare
# Processing Record 10 of Set 19 | necochea
# Processing Record 11 of Set 19 | kaitangata
# Processing Record 12 of Set 19 | belaya gora
# Processing Record 13 of Set 19 | amsterdam
# Processing Record 14 of Set 19 | chancay
# Processing Record 15 of Set 19 | skibbereen
# Processing Record 16 of Set 19 | saskylakh
# Processing Record 17 of Set 19 | santa maria
# Processing Record 18 of Set 19 | punakha
# Processing Record 19 of Set 19 | cabral
# Processing Record 20 of Set 19 | ostrovnoy
# Processing Record 21 of Set 19 | potosi
# Processing Record 22 of Set 19 | kamenka
# Processing Record 23 of Set 19 | arbroath
# Processing Record 24 of Set 19 | faya
# Processing Record 25 of Set 19 | ritchie
# Processing Record 26 of Set 19 | butaritari
# Processing Record 27 of Set 19 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 19 | howard springs
# Processing Record 29 of Set 19 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 19 | iquitos
# Processing Record 31 of Set 19 | benjamin constant
# Processing Record 32 of Set 19 | magaria
# Processing Record 33 of Set 19 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 19 | cabinda
# Processing Record 35 of Set 19 | sayaxche
# Processing Record 36 of Set 19 | north bend
# Processing Record 37 of Set 19 | richards bay
# Processing Record 38 of Set 19 | margate
# Processing Record 39 of Set 19 | gornopravdinsk
# Processing Record 40 of Set 19 | hambantota
# Processing Record 41 of Set 19 | adrar
# Processing Record 42 of Set 19 | haradok
# Processing Record 43 of Set 19 | andenes
# Processing Record 44 of Set 19 | kavieng
# Processing Record 45 of Set 19 | fez
# Processing Record 46 of Set 19 | todos santos
# Processing Record 47 of Set 19 | araquari
# Processing Record 48 of Set 19 | usuki
# Processing Record 49 of Set 19 | san andres
# Processing Record 50 of Set 19 | port lincoln
# Processing Record 1 of Set 20 | bandarbeyla
# Processing Record 2 of Set 20 | sao joao da barra
# Processing Record 3 of Set 20 | grosseto
# Processing Record 4 of Set 20 | haverfordwest
# Processing Record 5 of Set 20 | san patricio
# Processing Record 6 of Set 20 | sabaudia
# Processing Record 7 of Set 20 | portland
# Processing Record 8 of Set 20 | port shepstone
# Processing Record 9 of Set 20 | xining
# Processing Record 10 of Set 20 | yerbogachen
# Processing Record 11 of Set 20 | rocha
# Processing Record 12 of Set 20 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 20 | burdur
# Processing Record 14 of Set 20 | dharmanagar
# Processing Record 15 of Set 20 | la ronge
# Processing Record 16 of Set 20 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 20 | shumyachi
# Processing Record 18 of Set 20 | bundaberg
# Processing Record 19 of Set 20 | matara
# Processing Record 20 of Set 20 | campbellford
# Processing Record 21 of Set 20 | waingapu
# Processing Record 22 of Set 20 | san policarpo
# Processing Record 23 of Set 20 | staryy nadym
# Processing Record 24 of Set 20 | vardo
# Processing Record 25 of Set 20 | hami
# Processing Record 26 of Set 20 | marondera
# Processing Record 27 of Set 20 | segovia
# Processing Record 28 of Set 20 | mahebourg
# Processing Record 29 of Set 20 | rawson
# Processing Record 30 of Set 20 | chernyshkovskiy
# Processing Record 31 of Set 20 | mrirt
# City not found. Skipping...
# Processing Record 32 of Set 20 | acapulco
# Processing Record 33 of Set 20 | macamic
# Processing Record 34 of Set 20 | ngama
# Processing Record 35 of Set 20 | linden
# Processing Record 36 of Set 20 | alyangula
# Processing Record 37 of Set 20 | asau
# Processing Record 38 of Set 20 | severnyy
# Processing Record 39 of Set 20 | sabha
# Processing Record 40 of Set 20 | tura
# Processing Record 41 of Set 20 | kenai
# Processing Record 42 of Set 20 | avera
# Processing Record 43 of Set 20 | hamilton
# Processing Record 44 of Set 20 | koungheul
# Processing Record 45 of Set 20 | jacareacanga
# Processing Record 46 of Set 20 | kpandae
# Processing Record 47 of Set 20 | kuva
# City not found. Skipping...
# Processing Record 48 of Set 20 | paris
# Processing Record 49 of Set 20 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 20 | evensk
# Processing Record 1 of Set 21 | guerrero negro
# Processing Record 2 of Set 21 | esperance
# Processing Record 3 of Set 21 | belmonte
# Processing Record 4 of Set 21 | kokopo
# Processing Record 5 of Set 21 | medford
# Processing Record 6 of Set 21 | san bartolome de tirajana
# Processing Record 7 of Set 21 | lata
# Processing Record 8 of Set 21 | lavrentiya
# Processing Record 9 of Set 21 | tuktoyaktuk
# Processing Record 10 of Set 21 | mehamn
# Processing Record 11 of Set 21 | belle fourche
# Processing Record 12 of Set 21 | qaqortoq
# Processing Record 13 of Set 21 | provideniya
# Processing Record 14 of Set 21 | san isidro
# Processing Record 15 of Set 21 | zorgo
# Processing Record 16 of Set 21 | khatanga
# Processing Record 17 of Set 21 | balsas
# Processing Record 18 of Set 21 | tarime
# Processing Record 19 of Set 21 | srednekolymsk
# Processing Record 20 of Set 21 | chavakachcheri
# Processing Record 21 of Set 21 | canaries
# Processing Record 22 of Set 21 | tungkang
# City not found. Skipping...
# Processing Record 23 of Set 21 | general elizardo aquino
# Processing Record 24 of Set 21 | dunedin
# Processing Record 25 of Set 21 | hithadhoo
# Processing Record 26 of Set 21 | caribou
# Processing Record 27 of Set 21 | luebo
# Processing Record 28 of Set 21 | lujan
# Processing Record 29 of Set 21 | peno
# Processing Record 30 of Set 21 | taiobeiras
# Processing Record 31 of Set 21 | constitucion
# Processing Record 32 of Set 21 | camopi
# Processing Record 33 of Set 21 | suntar
# Processing Record 34 of Set 21 | namibe
# Processing Record 35 of Set 21 | alofi
# Processing Record 36 of Set 21 | iqaluit
# Processing Record 37 of Set 21 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 21 | makung
# City not found. Skipping...
# Processing Record 39 of Set 21 | lagoa
# Processing Record 40 of Set 21 | kysyl-syr
# Processing Record 41 of Set 21 | am timan
# Processing Record 42 of Set 21 | graaff-reinet
# Processing Record 43 of Set 21 | antofagasta
# Processing Record 44 of Set 21 | padang
# Processing Record 45 of Set 21 | francisco sa
# Processing Record 46 of Set 21 | burica
# City not found. Skipping...
# Processing Record 47 of Set 21 | teluk nibung
# Processing Record 48 of Set 21 | panzhihua
# Processing Record 49 of Set 21 | sinnamary
# Processing Record 50 of Set 21 | baglung
# Processing Record 1 of Set 22 | torbay
# Processing Record 2 of Set 22 | verkhnetulomskiy
# Processing Record 3 of Set 22 | husavik
# Processing Record 4 of Set 22 | abha
# Processing Record 5 of Set 22 | suez
# Processing Record 6 of Set 22 | caravelas
# Processing Record 7 of Set 22 | dwarka
# Processing Record 8 of Set 22 | traverse city
# Processing Record 9 of Set 22 | sobolevo
# Processing Record 10 of Set 22 | camocim
# Processing Record 11 of Set 22 | taltal
# Processing Record 12 of Set 22 | banjar
# Processing Record 13 of Set 22 | gondanglegi
# Processing Record 14 of Set 22 | rimbey
# Processing Record 15 of Set 22 | dandong
# Processing Record 16 of Set 22 | mana
# Processing Record 17 of Set 22 | ucluelet
# Processing Record 18 of Set 22 | vitorino freire
# Processing Record 19 of Set 22 | rock island
# Processing Record 20 of Set 22 | dekar
# Processing Record 21 of Set 22 | gazanjyk
# Processing Record 22 of Set 22 | ballina
# Processing Record 23 of Set 22 | lebanon
# Processing Record 24 of Set 22 | nelson bay
# Processing Record 25 of Set 22 | ongandjera
# Processing Record 26 of Set 22 | chicama
# Processing Record 27 of Set 22 | fortuna
# Processing Record 28 of Set 22 | bonthe
# Processing Record 29 of Set 22 | healdsburg
# Processing Record 30 of Set 22 | novyy urgal
# Processing Record 31 of Set 22 | lorengau
# Processing Record 32 of Set 22 | akdepe
# Processing Record 33 of Set 22 | ileza
# Processing Record 34 of Set 22 | searcy
# Processing Record 35 of Set 22 | olinda
# Processing Record 36 of Set 22 | maymyo
# Processing Record 37 of Set 22 | alamosa
# Processing Record 38 of Set 22 | naze
# Processing Record 39 of Set 22 | hurghada
# Processing Record 40 of Set 22 | dawson creek
# Processing Record 41 of Set 22 | collie
# Processing Record 42 of Set 22 | moerai
# Processing Record 43 of Set 22 | marawi
# Processing Record 44 of Set 22 | mackay
# Processing Record 45 of Set 22 | aswan
# Processing Record 46 of Set 22 | inhambane
# Processing Record 47 of Set 22 | rodrigues alves
# Processing Record 48 of Set 22 | lae
# Processing Record 49 of Set 22 | mitsamiouli
# Processing Record 50 of Set 22 | phu khieo
# City not found. Skipping...
# Processing Record 1 of Set 23 | ust-omchug
# Processing Record 2 of Set 23 | heinola
# Processing Record 3 of Set 23 | kanniyakumari
# Processing Record 4 of Set 23 | segezha
# Processing Record 5 of Set 23 | tautira
# Processing Record 6 of Set 23 | torres
# Processing Record 7 of Set 23 | ye
# City not found. Skipping...
# Processing Record 8 of Set 23 | pangkalanbuun
# Processing Record 9 of Set 23 | ilulissat
# Processing Record 10 of Set 23 | umm lajj
# Processing Record 11 of Set 23 | sao filipe
# Processing Record 12 of Set 23 | tshikapa
# Processing Record 13 of Set 23 | cosmopolis
# Processing Record 14 of Set 23 | boa vista
# Processing Record 15 of Set 23 | shkotovo-22
# City not found. Skipping...
# Processing Record 16 of Set 23 | rayong
# Processing Record 17 of Set 23 | sacueni
# Processing Record 18 of Set 23 | tuatapere
# Processing Record 19 of Set 23 | ous
# Processing Record 20 of Set 23 | oxford
# Processing Record 21 of Set 23 | mandurah
# Processing Record 22 of Set 23 | rakoczifalva
# Processing Record 23 of Set 23 | norman wells
# Processing Record 24 of Set 23 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 23 | varca
# Processing Record 26 of Set 23 | raahe
# Processing Record 27 of Set 23 | finschhafen
# Processing Record 28 of Set 23 | davila
# Processing Record 29 of Set 23 | lugovoy
# Processing Record 30 of Set 23 | svetlogorsk
# Processing Record 31 of Set 23 | marrakesh
# Processing Record 32 of Set 23 | ugoofaaru
# Processing Record 33 of Set 23 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 23 | isangel
# Processing Record 35 of Set 23 | pepperell
# Processing Record 36 of Set 23 | tazovskiy
# Processing Record 37 of Set 23 | manokwari
# Processing Record 38 of Set 23 | kathmandu
# Processing Record 39 of Set 23 | enshi
# Processing Record 40 of Set 23 | shingu
# Processing Record 41 of Set 23 | pochutla
# Processing Record 42 of Set 23 | beroroha
# Processing Record 43 of Set 23 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 23 | henderson
# Processing Record 45 of Set 23 | opuwo
# Processing Record 46 of Set 23 | cherskiy
# Processing Record 47 of Set 23 | chimore
# Processing Record 48 of Set 23 | big spring
# Processing Record 49 of Set 23 | mayo
# Processing Record 50 of Set 23 | rybachiy
# Processing Record 1 of Set 24 | ancud
# Processing Record 2 of Set 24 | aksarka
# Processing Record 3 of Set 24 | ruwi
# Processing Record 4 of Set 24 | neiafu
# Processing Record 5 of Set 24 | savannah bight
# Processing Record 6 of Set 24 | izumo
# Processing Record 7 of Set 24 | bilibino
# Processing Record 8 of Set 24 | codrington
# Processing Record 9 of Set 24 | san quintin
# Processing Record 10 of Set 24 | qui nhon
# Processing Record 11 of Set 24 | igrim
# Processing Record 12 of Set 24 | albanel
# Processing Record 13 of Set 24 | ivankiv
# Processing Record 14 of Set 24 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 24 | xinan
# Processing Record 16 of Set 24 | puri
# Processing Record 17 of Set 24 | rio grande
# Processing Record 18 of Set 24 | sovetskiy
# Processing Record 19 of Set 24 | tezu
# Processing Record 20 of Set 24 | cheuskiny
# City not found. Skipping...
# Processing Record 21 of Set 24 | russell
# Processing Record 22 of Set 24 | broome
# Processing Record 23 of Set 24 | veinticinco de mayo
# Processing Record 24 of Set 24 | dalvik
# Processing Record 25 of Set 24 | khonsa
# Processing Record 26 of Set 24 | filadelfia
# Processing Record 27 of Set 24 | kununurra
# Processing Record 28 of Set 24 | nipawin
# Processing Record 29 of Set 24 | kovur
# Processing Record 30 of Set 24 | anakapalle
# Processing Record 31 of Set 24 | belaya kholunitsa
# Processing Record 32 of Set 24 | xinglongshan
# Processing Record 33 of Set 24 | ostersund
# Processing Record 34 of Set 24 | iguape
# Processing Record 35 of Set 24 | eureka
# Processing Record 36 of Set 24 | byron bay
# Processing Record 37 of Set 24 | grande-synthe
# Processing Record 38 of Set 24 | storslett
# Processing Record 39 of Set 24 | sal rei
# Processing Record 40 of Set 24 | kogon
# Processing Record 41 of Set 24 | xingyi
# Processing Record 42 of Set 24 | maceio
# Processing Record 43 of Set 24 | vaniyambadi
# Processing Record 44 of Set 24 | hare bay
# Processing Record 45 of Set 24 | katangli
# Processing Record 46 of Set 24 | pendleton
# Processing Record 47 of Set 24 | medicine hat
# Processing Record 48 of Set 24 | nemuro
# Processing Record 49 of Set 24 | singaraja
# Processing Record 50 of Set 24 | half moon bay
# Processing Record 1 of Set 25 | kerman
# Processing Record 2 of Set 25 | bella vista
# Processing Record 3 of Set 25 | usta muhammad
# Processing Record 4 of Set 25 | farafangana
# Processing Record 5 of Set 25 | yen bai
# Processing Record 6 of Set 25 | boyolangu
# Processing Record 7 of Set 25 | impfondo
# Processing Record 8 of Set 25 | miraflores
# Processing Record 9 of Set 25 | torrington
# Processing Record 10 of Set 25 | bolec
# Processing Record 11 of Set 25 | christchurch
# Processing Record 12 of Set 25 | buin
# Processing Record 13 of Set 25 | ibra
# Processing Record 14 of Set 25 | port macquarie
# Processing Record 15 of Set 25 | garissa
# Processing Record 16 of Set 25 | coihaique
# Processing Record 17 of Set 25 | oksbol
# Processing Record 18 of Set 25 | robinson
# Processing Record 19 of Set 25 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 25 | saint-jean-port-joli
# Processing Record 21 of Set 25 | kodinsk
# Processing Record 22 of Set 25 | mount gambier
# Processing Record 23 of Set 25 | turukhansk
# Processing Record 24 of Set 25 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 25 | scarborough
# Processing Record 26 of Set 25 | hunza
# City not found. Skipping...
# Processing Record 27 of Set 25 | kilemary
# Processing Record 28 of Set 25 | makanya
# Processing Record 29 of Set 25 | el cairo
# Processing Record 30 of Set 25 | kavaratti
# Processing Record 31 of Set 25 | black river
# Processing Record 32 of Set 25 | aktas
# Processing Record 33 of Set 25 | yatou
# Processing Record 34 of Set 25 | mizan teferi
# Processing Record 35 of Set 25 | ust-nera
# Processing Record 36 of Set 25 | mugumu
# Processing Record 37 of Set 25 | pontes e lacerda
# Processing Record 38 of Set 25 | aklavik
# Processing Record 39 of Set 25 | changli
# Processing Record 40 of Set 25 | college
# Processing Record 41 of Set 25 | susehri
# Processing Record 42 of Set 25 | maniitsoq
# Processing Record 43 of Set 25 | yeppoon
# Processing Record 44 of Set 25 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 25 | tomatlan
# Processing Record 46 of Set 25 | lloro
# Processing Record 47 of Set 25 | solano
# Processing Record 48 of Set 25 | zhaotong
# Processing Record 49 of Set 25 | vila velha
# Processing Record 50 of Set 25 | tevriz
# Processing Record 1 of Set 26 | aguimes
# Processing Record 2 of Set 26 | alexandria
# Processing Record 3 of Set 26 | corn island
# Processing Record 4 of Set 26 | joensuu
# Processing Record 5 of Set 26 | lake city
# Processing Record 6 of Set 26 | arlit
# Processing Record 7 of Set 26 | mpongwe
# Processing Record 8 of Set 26 | kirakira
# Processing Record 9 of Set 26 | fukue
# Processing Record 10 of Set 26 | iraray
# Processing Record 11 of Set 26 | deputatskiy
# Processing Record 12 of Set 26 | mandiana
# Processing Record 13 of Set 26 | basay
# Processing Record 14 of Set 26 | cockburn town
# Processing Record 15 of Set 26 | vaitape
# Processing Record 16 of Set 26 | itatskiy
# Processing Record 17 of Set 26 | pimenteiras
# Processing Record 18 of Set 26 | sola
# Processing Record 19 of Set 26 | warrensburg
# Processing Record 20 of Set 26 | jacqueville
# Processing Record 21 of Set 26 | rodopolis
# Processing Record 22 of Set 26 | tual
# Processing Record 23 of Set 26 | oranjemund
# Processing Record 24 of Set 26 | sangar
# Processing Record 25 of Set 26 | saint-raymond
# Processing Record 26 of Set 26 | kruisfontein
# Processing Record 27 of Set 26 | karratha
# Processing Record 28 of Set 26 | ukiah
# Processing Record 29 of Set 26 | termoli
# Processing Record 30 of Set 26 | te anau
# Processing Record 31 of Set 26 | sayyan
# Processing Record 32 of Set 26 | puerto leguizamo
# Processing Record 33 of Set 26 | hay river
# Processing Record 34 of Set 26 | brae
# Processing Record 35 of Set 26 | khorixas
# Processing Record 36 of Set 26 | sibolga
# Processing Record 37 of Set 26 | resistencia
# Processing Record 38 of Set 26 | lensk
# Processing Record 39 of Set 26 | jardim
# Processing Record 40 of Set 26 | camacha
# Processing Record 41 of Set 26 | anadyr
# Processing Record 42 of Set 26 | mount isa
# Processing Record 43 of Set 26 | wajima
# Processing Record 44 of Set 26 | mogadishu
# Processing Record 45 of Set 26 | denia
# Processing Record 46 of Set 26 | eldikan
# City not found. Skipping...
# Processing Record 47 of Set 26 | san jose iturbide
# Processing Record 48 of Set 26 | bela
# Processing Record 49 of Set 26 | kostyantynivka
# Processing Record 50 of Set 26 | boca do acre
# Processing Record 1 of Set 27 | quatre cocos
# Processing Record 2 of Set 27 | port blair
# Processing Record 3 of Set 27 | aykhal
# Processing Record 4 of Set 27 | shipitsyno
# Processing Record 5 of Set 27 | iraucuba
# Processing Record 6 of Set 27 | khartoum
# Processing Record 7 of Set 27 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 27 | bindura
# Processing Record 9 of Set 27 | kazalinsk
# City not found. Skipping...
# Processing Record 10 of Set 27 | miri
# Processing Record 11 of Set 27 | thinadhoo
# Processing Record 12 of Set 27 | seinajoki
# Processing Record 13 of Set 27 | wanning
# Processing Record 14 of Set 27 | puerto asis
# Processing Record 15 of Set 27 | puerto suarez
# Processing Record 16 of Set 27 | phonhong
# Processing Record 17 of Set 27 | voznesenye
# Processing Record 18 of Set 27 | tawau
# Processing Record 19 of Set 27 | basco
# Processing Record 20 of Set 27 | hauterive
# Processing Record 21 of Set 27 | morehead
# Processing Record 22 of Set 27 | hirado
# Processing Record 23 of Set 27 | gondar
# Processing Record 24 of Set 27 | khandwa
# Processing Record 25 of Set 27 | viransehir
# Processing Record 26 of Set 27 | shakawe
# Processing Record 27 of Set 27 | dibaya
# City not found. Skipping...
# Processing Record 28 of Set 27 | victoria
# Processing Record 29 of Set 27 | shimoda
# Processing Record 30 of Set 27 | gat
# Processing Record 31 of Set 27 | sisimiut
# Processing Record 32 of Set 27 | higuey
# City not found. Skipping...
# Processing Record 33 of Set 27 | nalut
# Processing Record 34 of Set 27 | corumba
# Processing Record 35 of Set 27 | axim
# Processing Record 36 of Set 27 | kuryk
# Processing Record 37 of Set 27 | burnie
# Processing Record 38 of Set 27 | el alto
# Processing Record 39 of Set 27 | kralendijk
# Processing Record 40 of Set 27 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 27 | takoradi
# Processing Record 42 of Set 27 | anju
# Processing Record 43 of Set 27 | weihe
# Processing Record 44 of Set 27 | boddam
# Processing Record 45 of Set 27 | bouca
# Processing Record 46 of Set 27 | marzuq
# Processing Record 47 of Set 27 | pirgos
# Processing Record 48 of Set 27 | roald
# Processing Record 49 of Set 27 | karema
# Processing Record 50 of Set 27 | sawtell
# Processing Record 1 of Set 28 | kendari
# Processing Record 2 of Set 28 | salina
# Processing Record 3 of Set 28 | cayenne
# Processing Record 4 of Set 28 | kazachinskoye
# Processing Record 5 of Set 28 | chapais
# Processing Record 6 of Set 28 | oudtshoorn
# Processing Record 7 of Set 28 | rio bravo
# Processing Record 8 of Set 28 | zaozerne
# Processing Record 9 of Set 28 | karmana
# City not found. Skipping...
# Processing Record 10 of Set 28 | valparaiso
# Processing Record 11 of Set 28 | kasongo-lunda
# Processing Record 12 of Set 28 | plymouth
# Processing Record 13 of Set 28 | zyryanka
# Processing Record 14 of Set 28 | san cristobal
# Processing Record 15 of Set 28 | toulepleu
# City not found. Skipping...
# Processing Record 16 of Set 28 | indiaroba
# Processing Record 17 of Set 28 | guangyuan
# Processing Record 18 of Set 28 | barbastro
# Processing Record 19 of Set 28 | alappuzha
# Processing Record 20 of Set 28 | mahon
# Processing Record 21 of Set 28 | ust-uda
# Processing Record 22 of Set 28 | havoysund
# Processing Record 23 of Set 28 | nyrob
# Processing Record 24 of Set 28 | chikwawa
# Processing Record 25 of Set 28 | hangu
# Processing Record 26 of Set 28 | riyadh
# Processing Record 27 of Set 28 | namatanai
# Processing Record 28 of Set 28 | monywa
# Processing Record 29 of Set 28 | sodertalje
# City not found. Skipping...
# Processing Record 30 of Set 28 | acandi
# Processing Record 31 of Set 28 | galle
# Processing Record 32 of Set 28 | ahuimanu
# Processing Record 33 of Set 28 | laredo
# Processing Record 34 of Set 28 | deniliquin
# Processing Record 35 of Set 28 | dinsor
# City not found. Skipping...
# Processing Record 36 of Set 28 | nhamunda
# Processing Record 37 of Set 28 | baykit
# Processing Record 38 of Set 28 | nioro
# Processing Record 39 of Set 28 | maarianhamina
# Processing Record 40 of Set 28 | darhan
# Processing Record 41 of Set 28 | santo tomas
# Processing Record 42 of Set 28 | barcelos
# Processing Record 43 of Set 28 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 28 | ceres
# Processing Record 45 of Set 28 | birkenfeld
# Processing Record 46 of Set 28 | jiroft
# City not found. Skipping...
# Processing Record 47 of Set 28 | vostok
# Processing Record 48 of Set 28 | skjervoy
# Processing Record 49 of Set 28 | mackenzie
# Processing Record 50 of Set 28 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 29 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 29 | veraval
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_3_df = pd.DataFrame(city_data_3)
city_data_3_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton      AU -33.6500  115.3333     65.08        89           0
# 1         Ushuaia      AR -54.8000  -68.3000     49.66        87         100
# 2           Manta      EC  -0.9500  -80.7333     82.18        74          40
# 3          Sabang      ID   5.8933   95.3214     82.29        71          19
# 4         Bubaque      GW  11.2833  -15.8333     78.19        72         100
# 5    Punta Arenas      CL -53.1500  -70.9167     53.71        62          75
# 6           Bluff      NZ -46.6000  168.3333     61.81        88         100
# 7       San Borja      BO -14.8167  -66.8500     81.39        74          76
# 8  Krasnyy Chikoy      RU  50.3643  108.7512    -18.26       100          96
# 9        Shahreza      IR  32.0339   51.8794     37.13        32           0
#
#    Wind Speed      Weather Desc
# 0       15.55         clear sky
# 1       17.27        light rain
# 2        8.05  scattered clouds
# 3        9.73        few clouds
# 4       21.52   overcast clouds
# 5       14.97        light rain
# 6        6.85        light rain
# 7        3.29     broken clouds
# 8        1.63   overcast clouds
# 9        5.14         clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_3_df.to_csv(output_data_file, index_label="City_ID")
